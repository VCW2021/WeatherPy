# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit
# Import the API key.
from config import weather_api_key

from datetime import datetime

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. 
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(-64.54996075838372, 60.631492793935934), (86.20800296866315, 49.13421220280176), (86.6425431886899, -123.97322538733258), (54.9164204063529, 161.19271670606685), (56.03720104964992, 36.229798213946594), (-20.64776305040735, -31.18672228655575), (9.766699320668437, -78.87718309995104), (-7.543035206031249, 175.8560251348107), (-6.157643338826901, -79.39712352601266), (-27.428853395779655, -144.2815698975655), (-19.169797419491857, 86.98463197586477), (-24.582887373750125, 24.559630048576537), (75.39899806566169, -159.28594566797392), (-83.6558804144067, 8.715405521260465), (7.119259034146708, 39.27180623424229), (-24.31465788211412, 0.392072261272574), (83.11224202200103, 139.10350989627773), (-71.94062257671513, 64.69219275529827), (-67.60376887149815, 131.71312291378752), (7.731456825667806, 172.99878213411307), (33.759660956687014, 95.63639341844004), (-68.59767372415634, 95.16430311885631), (56.780382569473545, 41.54466083003044), (52.8863014426133, 91.94881015148644), (-84.39954858427144, 121.77596536372056), (72.23540843595106, 37.55088443722681), (10.911503853154471, 134.51234786408264), (30.45700292676416, -115.5870763954238), (-59.18293987087341, 136.3810480604812), (-18.605999058787447, 110.77820787555675), (-54.760625751728185, -80.6657971742126), (16.856418449773102, -115.31663219189961), (31.470264209313683, -6.6016830331793415), (71.48194858747158, -9.497327339080954), (15.508109826201604, 147.09248096067387), (-21.819424804611657, -46.65486376894066), (49.43236973477241, 149.47553865995394), (-65.68986834260781, -20.075889468457376), (62.59726564816333, 69.0206086589736), (-16.510654007422588, 87.45835094757712), (-84.5098334316782, -83.98004075106302), (49.41913324999558, -69.0651526015132), (86.26588574950406, 18.228617315003135), (-12.179211964229154, 9.496209539850042), (82.94025321833766, 2.6135863094673084), (-1.7398103279103339, 126.89687448720946), (12.443933892355048, 56.98856948220819), (68.20945883887401, 54.359343606972686), (69.50279563237362, 150.34135962094962), (32.97271209586087, 21.88018911071015), (-21.54639431608939, 32.871891068709374), (-44.084470497740824, 79.3001729638276), (-25.72505859498257, -34.16151603443163), (-71.44220431950853, 176.09670765421333), (32.0310430001215, 13.185957100749704), (23.892622234302934, 18.171271504316536), (11.502476783389938, 93.19575104738612), (-14.80180334999605, 107.12539632620519), (-76.91426144422641, -111.56179975193899), (-64.4770424498295, 19.38306403269496), (-13.899713860800816, -72.97672078494831), (2.206870536826912, -44.40670334105769), (56.563417464208214, -98.31413581303704), (36.29188478630084, -169.25644751807806), (87.07769455070527, -85.96122640043173), (31.93903653634456, 164.67321756941254), (88.74227282747557, -48.76072634733629), (62.36240576902941, -142.617345212895), (-60.81411995850395, -112.97661159027426), (22.7695247200176, -157.9713236806646), (-51.05641747300059, 43.19459656721506), (-74.09678575567555, 78.92531504262593), (-69.10071361237578, -127.14745562095459), (32.8415493817823, -17.954298860300383), (-23.817884054935334, -26.962546552474407), (5.120196106036261, -85.18280589188339), (-32.87316788268166, -145.66400017541835), (64.14974044683242, -146.10647501134028), (56.68666632580437, -74.299241079861), (-0.006293458666604579, -130.46016281592378), (-64.89452287656368, 82.03450214948901), (51.32005250361186, -158.98792356785086), (-26.50242807368302, -56.836811025115395), (-64.75154387700309, -162.81897639776923), (-82.18074346520905, 95.280467527633), (51.82914330312141, 15.456389694087363), (37.09304149364792, 158.53461225415657), (-55.05022623805728, 157.99664642296744), (4.726338928546497, 154.25661528714699), (-56.365091221702166, 95.07160313156191), (39.34078310844029, 11.389476754383196), (-84.27979454574057, -125.68677930834522), (80.64682526164816, -53.01955114709881), (-5.874280825660264, -79.42590744458941), (-76.79807788563946, 178.81517700129643), (34.936241454787634, -161.18294703065587), (42.95651313007 ...

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
city_data = []
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']

        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })


# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1485c80207d1d8799c539412e984bee2
# Processing Record 1 of Set 1 | gasa
# Processing Record 2 of Set 1 | bulungu
# Processing Record 3 of Set 1 | wakkanai
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | salalah
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | ampanihy
# Processing Record 11 of Set 1 | esperance
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | toamasina
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | tessalit
# Processing Record 19 of Set 1 | longyearbyen
# Processing Record 20 of Set 1 | luderitz
# Processing Record 21 of Set 1 | beringovskiy
# Processing Record 22 of Set 1 | ponta do sol
# Processing Record 23 of Set 1 | cabo san lucas
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | santo anastacio
# Processing Record 26 of Set 1 | sao filipe
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | beyneu
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | carikar
# City not found. Skipping...
# Processing Record 32 of Set 1 | newport
# Processing Record 33 of Set 1 | kloulklubed
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | mount gambier
# Processing Record 36 of Set 1 | havelock
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | saskylakh
# Processing Record 39 of Set 1 | kahului
# Processing Record 40 of Set 1 | murray bridge
# Processing Record 41 of Set 1 | rawson
# Processing Record 42 of Set 1 | margate
# Processing Record 43 of Set 1 | skibbereen
# Processing Record 44 of Set 1 | bengkulu
# Processing Record 45 of Set 1 | uk
# City not found. Skipping...
# Processing Record 46 of Set 1 | vao
# Processing Record 47 of Set 1 | agsu
# City not found. Skipping...
# Processing Record 48 of Set 1 | marktheidenfeld
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | wattegama
# Processing Record 3 of Set 2 | ojuelos de jalisco
# Processing Record 4 of Set 2 | zaysan
# Processing Record 5 of Set 2 | faanui
# Processing Record 6 of Set 2 | klaksvik
# Processing Record 7 of Set 2 | puerto baquerizo moreno
# Processing Record 8 of Set 2 | kodiak
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | jiwani
# Processing Record 11 of Set 2 | burnie
# Processing Record 12 of Set 2 | pirogovo
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | chernyshevskiy
# Processing Record 15 of Set 2 | hambantota
# Processing Record 16 of Set 2 | port hardy
# Processing Record 17 of Set 2 | padang
# Processing Record 18 of Set 2 | jalu
# Processing Record 19 of Set 2 | mount darwin
# Processing Record 20 of Set 2 | saint-philippe
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 2 | mataura
# Processing Record 23 of Set 2 | alyangula
# Processing Record 24 of Set 2 | egvekinot
# Processing Record 25 of Set 2 | buraydah
# Processing Record 26 of Set 2 | tasiilaq
# Processing Record 27 of Set 2 | carnarvon
# Processing Record 28 of Set 2 | turkistan
# Processing Record 29 of Set 2 | victoria
# Processing Record 30 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 2 | hami
# Processing Record 32 of Set 2 | deputatskiy
# Processing Record 33 of Set 2 | ozgon
# City not found. Skipping...
# Processing Record 34 of Set 2 | helena
# Processing Record 35 of Set 2 | koksovyy
# Processing Record 36 of Set 2 | kruisfontein
# Processing Record 37 of Set 2 | neuquen
# Processing Record 38 of Set 2 | northam
# Processing Record 39 of Set 2 | meulaboh
# Processing Record 40 of Set 2 | goderich
# Processing Record 41 of Set 2 | medina del campo
# Processing Record 42 of Set 2 | charters towers
# Processing Record 43 of Set 2 | chokwe
# Processing Record 44 of Set 2 | sisophon
# Processing Record 45 of Set 2 | doctor juan leon mallorquin
# Processing Record 46 of Set 2 | berberati
# Processing Record 47 of Set 2 | markova
# Processing Record 48 of Set 2 | lebork
# Processing Record 49 of Set 2 | grand-santi
# Processing Record 50 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 3 | hovin
# Processing Record 3 of Set 3 | yulara
# Processing Record 4 of Set 3 | tuktoyaktuk
# Processing Record 5 of Set 3 | half moon bay
# Processing Record 6 of Set 3 | oshnaviyeh
# Processing Record 7 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 3 | baykit
# Processing Record 9 of Set 3 | baripada
# Processing Record 10 of Set 3 | douentza
# Processing Record 11 of Set 3 | boddam
# Processing Record 12 of Set 3 | grimari
# City not found. Skipping...
# Processing Record 13 of Set 3 | boyolangu
# Processing Record 14 of Set 3 | vila velha
# Processing Record 15 of Set 3 | codrington
# Processing Record 16 of Set 3 | olafsvik
# Processing Record 17 of Set 3 | kaitangata
# Processing Record 18 of Set 3 | touros
# Processing Record 19 of Set 3 | takapau
# Processing Record 20 of Set 3 | yellowknife
# Processing Record 21 of Set 3 | grindavik
# Processing Record 22 of Set 3 | ribeira grande
# Processing Record 23 of Set 3 | bethal
# Processing Record 24 of Set 3 | vaini
# Processing Record 25 of Set 3 | taksimo
# Processing Record 26 of Set 3 | atar
# Processing Record 27 of Set 3 | placido de castro
# Processing Record 28 of Set 3 | palmas
# Processing Record 29 of Set 3 | banda aceh
# Processing Record 30 of Set 3 | dunedin
# Processing Record 31 of Set 3 | tornio
# Processing Record 32 of Set 3 | ust-tsilma
# Processing Record 33 of Set 3 | itororo
# Processing Record 34 of Set 3 | muros
# Processing Record 35 of Set 3 | poum
# Processing Record 36 of Set 3 | saint george
# Processing Record 37 of Set 3 | saldanha
# Processing Record 38 of Set 3 | berlevag
# Processing Record 39 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 3 | dwarka
# Processing Record 41 of Set 3 | port alfred
# Processing Record 42 of Set 3 | guerrero negro
# Processing Record 43 of Set 3 | lebu
# Processing Record 44 of Set 3 | cochrane
# Processing Record 45 of Set 3 | sabang
# Processing Record 46 of Set 3 | budureasa
# Processing Record 47 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 3 | upernavik
# Processing Record 49 of Set 3 | calama
# Processing Record 50 of Set 3 | aleksandrovskiy zavod
# Processing Record 1 of Set 4 | beloha
# Processing Record 2 of Set 4 | acapulco
# Processing Record 3 of Set 4 | bambous virieux
# Processing Record 4 of Set 4 | cherskiy
# Processing Record 5 of Set 4 | lavrentiya
# Processing Record 6 of Set 4 | povenets
# Processing Record 7 of Set 4 | makakilo city
# Processing Record 8 of Set 4 | arraial do cabo
# Processing Record 9 of Set 4 | panaba
# Processing Record 10 of Set 4 | maicao
# Processing Record 11 of Set 4 | skjervoy
# Processing Record 12 of Set 4 | hermanus
# Processing Record 13 of Set 4 | clinton
# Processing Record 14 of Set 4 | puerto narino
# Processing Record 15 of Set 4 | kavieng
# Processing Record 16 of Set 4 | khash
# Processing Record 17 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 18 of Set 4 | coquimbo
# Processing Record 19 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 4 | avera
# Processing Record 21 of Set 4 | karangasem
# Processing Record 22 of Set 4 | talara
# Processing Record 23 of Set 4 | qostanay
# Processing Record 24 of Set 4 | innisfail
# Processing Record 25 of Set 4 | yarada
# Processing Record 26 of Set 4 | san lorenzo
# Processing Record 27 of Set 4 | puerto escondido
# Processing Record 28 of Set 4 | isla mujeres
# Processing Record 29 of Set 4 | lang son
# Processing Record 30 of Set 4 | clyde river
# Processing Record 31 of Set 4 | chokurdakh
# Processing Record 32 of Set 4 | sal rei
# Processing Record 33 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 4 | katherine
# Processing Record 35 of Set 4 | binga
# Processing Record 36 of Set 4 | caravelas
# Processing Record 37 of Set 4 | vytegra
# Processing Record 38 of Set 4 | tual
# Processing Record 39 of Set 4 | barmer
# Processing Record 40 of Set 4 | sinjar
# Processing Record 41 of Set 4 | fukue
# Processing Record 42 of Set 4 | lorengau
# Processing Record 43 of Set 4 | zalantun
# Processing Record 44 of Set 4 | mar del plata
# Processing Record 45 of Set 4 | manono
# Processing Record 46 of Set 4 | east london
# Processing Record 47 of Set 4 | rolim de moura
# City not found. Skipping...
# Processing Record 48 of Set 4 | kathu
# Processing Record 49 of Set 4 | ust-maya
# Processing Record 50 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 1 of Set 5 | grenada
# Processing Record 2 of Set 5 | hamilton
# Processing Record 3 of Set 5 | rincon
# Processing Record 4 of Set 5 | inuvik
# Processing Record 5 of Set 5 | husavik
# Processing Record 6 of Set 5 | airai
# Processing Record 7 of Set 5 | tiksi
# Processing Record 8 of Set 5 | belmonte
# Processing Record 9 of Set 5 | harper
# Processing Record 10 of Set 5 | mansehra
# Processing Record 11 of Set 5 | taraz
# Processing Record 12 of Set 5 | neka
# Processing Record 13 of Set 5 | kaeo
# Processing Record 14 of Set 5 | keetmanshoop
# Processing Record 15 of Set 5 | acarau
# Processing Record 16 of Set 5 | sigli
# Processing Record 17 of Set 5 | nizhneangarsk
# Processing Record 18 of Set 5 | banmo
# City not found. Skipping...
# Processing Record 19 of Set 5 | prachuap khiri khan
# Processing Record 20 of Set 5 | thompson
# Processing Record 21 of Set 5 | san jose
# Processing Record 22 of Set 5 | mittersill
# Processing Record 23 of Set 5 | norman wells
# Processing Record 24 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 25 of Set 5 | hofn
# Processing Record 26 of Set 5 | buta
# Processing Record 27 of Set 5 | oranjemund
# Processing Record 28 of Set 5 | bredasdorp
# Processing Record 29 of Set 5 | nantucket
# Processing Record 30 of Set 5 | raahe
# Processing Record 31 of Set 5 | saint-louis
# Processing Record 32 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 34 of Set 5 | mwinilunga
# Processing Record 35 of Set 5 | puerto leguizamo
# Processing Record 36 of Set 5 | yar-sale
# Processing Record 37 of Set 5 | catuday
# Processing Record 38 of Set 5 | torbay
# Processing Record 39 of Set 5 | catalao
# Processing Record 40 of Set 5 | sawakin
# Processing Record 41 of Set 5 | weingarten
# Processing Record 42 of Set 5 | georgetown
# Processing Record 43 of Set 5 | shirokiy
# Processing Record 44 of Set 5 | dhidhdhoo
# Processing Record 45 of Set 5 | rabat
# Processing Record 46 of Set 5 | viedma
# Processing Record 47 of Set 5 | isangel
# Processing Record 48 of Set 5 | chuy
# Processing Record 49 of Set 5 | carutapera
# Processing Record 50 of Set 5 | lodja
# Processing Record 1 of Set 6 | itaguai
# Processing Record 2 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 6 | kutum
# Processing Record 4 of Set 6 | sioux lookout
# Processing Record 5 of Set 6 | severo-kurilsk
# Processing Record 6 of Set 6 | vila franca do campo
# Processing Record 7 of Set 6 | atka
# City not found. Skipping...
# Processing Record 8 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 9 of Set 6 | college
# Processing Record 10 of Set 6 | kedrovyy
# Processing Record 11 of Set 6 | acutzilapan
# City not found. Skipping...
# Processing Record 12 of Set 6 | mayumba
# Processing Record 13 of Set 6 | vestmannaeyjar
# Processing Record 14 of Set 6 | puerto penasco
# Processing Record 15 of Set 6 | warrington
# Processing Record 16 of Set 6 | maniitsoq
# Processing Record 17 of Set 6 | makat
# Processing Record 18 of Set 6 | baghdad
# Processing Record 19 of Set 6 | provideniya
# Processing Record 20 of Set 6 | san cristobal
# Processing Record 21 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 6 | barra
# Processing Record 23 of Set 6 | sarangani
# Processing Record 24 of Set 6 | hervey bay
# Processing Record 25 of Set 6 | doka
# Processing Record 26 of Set 6 | sulangan
# Processing Record 27 of Set 6 | shitanjing
# Processing Record 28 of Set 6 | cidreira
# Processing Record 29 of Set 6 | nemuro
# Processing Record 30 of Set 6 | steamboat springs
# Processing Record 31 of Set 6 | hohhot
# Processing Record 32 of Set 6 | sand springs
# Processing Record 33 of Set 6 | hualmay
# Processing Record 34 of Set 6 | trinidad
# Processing Record 35 of Set 6 | aripuana
# Processing Record 36 of Set 6 | kyabe
# Processing Record 37 of Set 6 | port-cartier
# Processing Record 38 of Set 6 | muroto
# Processing Record 39 of Set 6 | montanha
# Processing Record 40 of Set 6 | fez
# Processing Record 41 of Set 6 | borodino
# Processing Record 42 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 6 | san patricio
# Processing Record 44 of Set 6 | kieta
# Processing Record 45 of Set 6 | oranjestad
# Processing Record 46 of Set 6 | sergeyevka
# Processing Record 47 of Set 6 | wukari
# Processing Record 48 of Set 6 | teshie
# Processing Record 49 of Set 6 | dickinson
# Processing Record 50 of Set 6 | abu kamal
# Processing Record 1 of Set 7 | palmer
# Processing Record 2 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 3 of Set 7 | honiara
# Processing Record 4 of Set 7 | nome
# Processing Record 5 of Set 7 | betsiamites
# Processing Record 6 of Set 7 | santa cruz
# Processing Record 7 of Set 7 | bathsheba
# Processing Record 8 of Set 7 | lasa
# Processing Record 9 of Set 7 | komsomolskiy
# Processing Record 10 of Set 7 | san carlos
# Processing Record 11 of Set 7 | guajara-mirim
# City not found. Skipping...
# Processing Record 12 of Set 7 | longhua
# Processing Record 13 of Set 7 | port blair
# Processing Record 14 of Set 7 | ancud
# Processing Record 15 of Set 7 | puri
# Processing Record 16 of Set 7 | bilma
# Processing Record 17 of Set 7 | mackenzie
# Processing Record 18 of Set 7 | mouzouras
# Processing Record 19 of Set 7 | boende
# Processing Record 20 of Set 7 | harwich
# Processing Record 21 of Set 7 | tiznit
# Processing Record 22 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 7 | turmalina
# Processing Record 24 of Set 7 | oreanda
# City not found. Skipping...
# Processing Record 25 of Set 7 | geraldton
# Processing Record 26 of Set 7 | pecos
# Processing Record 27 of Set 7 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 7 | bollnas
# Processing Record 29 of Set 7 | doctor arroyo
# Processing Record 30 of Set 7 | kaoma
# Processing Record 31 of Set 7 | castro
# Processing Record 32 of Set 7 | namibe
# Processing Record 33 of Set 7 | port macquarie
# Processing Record 34 of Set 7 | andenes
# Processing Record 35 of Set 7 | tuatapere
# Processing Record 36 of Set 7 | saint anthony
# Processing Record 37 of Set 7 | mizan teferi
# Processing Record 38 of Set 7 | paka
# Processing Record 39 of Set 7 | gat
# Processing Record 40 of Set 7 | port elizabeth
# Processing Record 41 of Set 7 | fonte boa
# Processing Record 42 of Set 7 | griffith
# Processing Record 43 of Set 7 | bethel
# Processing Record 44 of Set 7 | dubuque
# Processing Record 45 of Set 7 | nampula
# Processing Record 46 of Set 7 | annau
# Processing Record 47 of Set 7 | alice springs
# Processing Record 48 of Set 7 | epiniana
# Processing Record 49 of Set 7 | katsuura
# Processing Record 50 of Set 7 | zetaquira
# Processing Record 1 of Set 8 | sao domingos
# Processing Record 2 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 8 | ilulissat
# Processing Record 4 of Set 8 | ejido
# Processing Record 5 of Set 8 | teguise
# Processing Record 6 of Set 8 | beaverlodge
# Processing Record 7 of Set 8 | batticaloa
# Processing Record 8 of Set 8 | leh
# Processing Record 9 of Set 8 | esfarayen
# Processing Record 10 of Set 8 | launceston
# Processing Record 11 of Set 8 | springhill
# Processing Record 12 of Set 8 | iranshahr
# Processing Record 13 of Set 8 | kautokeino
# Processing Record 14 of Set 8 | sitka
# Processing Record 15 of Set 8 | fort myers beach
# Processing Record 16 of Set 8 | kiruna
# Processing Record 17 of Set 8 | toora-khem
# Processing Record 18 of Set 8 | taltal
# Processing Record 19 of Set 8 | seoul
# Processing Record 20 of Set 8 | constitucion
# Processing Record 21 of Set 8 | macherla
# Processing Record 22 of Set 8 | karratha
# Processing Record 23 of Set 8 | asau
# Processing Record 24 of Set 8 | mjolby
# Processing Record 25 of Set 8 | ferme-neuve
# Processing Record 26 of Set 8 | lagoa
# Processing Record 27 of Set 8 | lisala
# Processing Record 28 of Set 8 | lagos
# Processing Record 29 of Set 8 | port hedland
# Processing Record 30 of Set 8 | brae
# Processing Record 31 of Set 8 | shimanovsk
# Processing Record 32 of Set 8 | una
# Processing Record 33 of Set 8 | mount pleasant
# Processing Record 34 of Set 8 | vung tau
# Processing Record 35 of Set 8 | vardo
# Processing Record 36 of Set 8 | dubbo
# Processing Record 37 of Set 8 | sur
# Processing Record 38 of Set 8 | narasannapeta
# Processing Record 39 of Set 8 | daliang
# Processing Record 40 of Set 8 | talaya
# Processing Record 41 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 8 | laguna
# Processing Record 43 of Set 8 | presidencia roque saenz pena
# Processing Record 44 of Set 8 | tecpan
# Processing Record 45 of Set 8 | chumphon
# Processing Record 46 of Set 8 | vila
# Processing Record 47 of Set 8 | fare
# Processing Record 48 of Set 8 | talnakh
# Processing Record 49 of Set 8 | neuenhagen
# Processing Record 50 of Set 8 | banjar
# Processing Record 1 of Set 9 | manokwari
# Processing Record 2 of Set 9 | assiniboia
# Processing Record 3 of Set 9 | guangyuan
# Processing Record 4 of Set 9 | zheleznodorozhnyy
# Processing Record 5 of Set 9 | homestead
# Processing Record 6 of Set 9 | kologriv
# Processing Record 7 of Set 9 | west bay
# Processing Record 8 of Set 9 | patrocinio
# Processing Record 9 of Set 9 | charlestown
# Processing Record 10 of Set 9 | westport
# Processing Record 11 of Set 9 | kavaratti
# Processing Record 12 of Set 9 | alofi
# Processing Record 13 of Set 9 | lompoc
# Processing Record 14 of Set 9 | leningradskiy
# Processing Record 15 of Set 9 | lardos
# Processing Record 16 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 9 | san antonio
# Processing Record 18 of Set 9 | guaruja
# Processing Record 19 of Set 9 | nurota
# Processing Record 20 of Set 9 | boa vista
# Processing Record 21 of Set 9 | iqaluit
# Processing Record 22 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 23 of Set 9 | inirida
# Processing Record 24 of Set 9 | moura
# Processing Record 25 of Set 9 | colares
# Processing Record 26 of Set 9 | mabaruma
# Processing Record 27 of Set 9 | vyshkov
# Processing Record 28 of Set 9 | ascension
# Processing Record 29 of Set 9 | fort nelson
# Processing Record 30 of Set 9 | muzquiz
# City not found. Skipping...
# Processing Record 31 of Set 9 | ohrid
# Processing Record 32 of Set 9 | aklavik
# Processing Record 33 of Set 9 | cacapava do sul
# Processing Record 34 of Set 9 | kenai
# Processing Record 35 of Set 9 | ust-kuyga
# Processing Record 36 of Set 9 | shahr-e babak
# Processing Record 37 of Set 9 | anadyr
# Processing Record 38 of Set 9 | poya
# Processing Record 39 of Set 9 | zhigansk
# Processing Record 40 of Set 9 | zhangjiakou
# Processing Record 41 of Set 9 | bagdarin
# Processing Record 42 of Set 9 | belen
# Processing Record 43 of Set 9 | iroquois falls
# Processing Record 44 of Set 9 | omsukchan
# Processing Record 45 of Set 9 | dingle
# Processing Record 46 of Set 9 | ambulu
# Processing Record 47 of Set 9 | oppdal
# Processing Record 48 of Set 9 | yerbogachen
# Processing Record 49 of Set 9 | port augusta
# Processing Record 50 of Set 9 | tahta
# Processing Record 1 of Set 10 | ofaqim
# Processing Record 2 of Set 10 | hokitika
# Processing Record 3 of Set 10 | cockburn town
# Processing Record 4 of Set 10 | envira
# Processing Record 5 of Set 10 | suluq
# Processing Record 6 of Set 10 | auki
# Processing Record 7 of Set 10 | karakose
# City not found. Skipping...
# Processing Record 8 of Set 10 | maraba
# Processing Record 9 of Set 10 | trincomalee
# Processing Record 10 of Set 10 | jieshi
# Processing Record 11 of Set 10 | sarkand
# Processing Record 12 of Set 10 | mesyagutovo
# Processing Record 13 of Set 10 | ponta delgada
# Processing Record 14 of Set 10 | kiama
# Processing Record 15 of Set 10 | taoudenni
# Processing Record 16 of Set 10 | micoud
# Processing Record 17 of Set 10 | flin flon
# Processing Record 18 of Set 10 | salina cruz
# Processing Record 19 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 20 of Set 10 | valkeala
# Processing Record 21 of Set 10 | ewa beach
# Processing Record 22 of Set 10 | hope
# Processing Record 23 of Set 10 | nuuk
# Processing Record 24 of Set 10 | vanavara
# Processing Record 25 of Set 10 | itigi
# Processing Record 26 of Set 10 | veraval
# Processing Record 27 of Set 10 | quchan
# Processing Record 28 of Set 10 | sao miguel do araguaia
# Processing Record 29 of Set 10 | port lincoln
# Processing Record 30 of Set 10 | pevek
# Processing Record 31 of Set 10 | rypefjord
# Processing Record 32 of Set 10 | kalomo
# City not found. Skipping...
# Processing Record 33 of Set 10 | saint-cyr-sur-loire
# Processing Record 34 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 35 of Set 10 | pesqueira
# Processing Record 36 of Set 10 | san quintin
# Processing Record 37 of Set 10 | oktyabrskiy
# Processing Record 38 of Set 10 | henties bay
# Processing Record 39 of Set 10 | demba
# Processing Record 40 of Set 10 | la ronge
# Processing Record 41 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 42 of Set 10 | novopokrovka
# Processing Record 43 of Set 10 | sinnamary
# Processing Record 44 of Set 10 | guanica
# Processing Record 45 of Set 10 | cehegin
# Processing Record 46 of Set 10 | samarai
# Processing Record 47 of Set 10 | yuryev-polskiy
# Processing Record 48 of Set 10 | necochea
# Processing Record 49 of Set 10 | barao de melgaco
# Processing Record 50 of Set 10 | bandarbeyla
# Processing Record 1 of Set 11 | dharmavaram
# Processing Record 2 of Set 11 | terrak
# Processing Record 3 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 4 of Set 11 | mahebourg
# Processing Record 5 of Set 11 | bubaque
# Processing Record 6 of Set 11 | praia
# Processing Record 7 of Set 11 | rio rancho
# Processing Record 8 of Set 11 | pochutla
# Processing Record 9 of Set 11 | ust-omchug
# Processing Record 10 of Set 11 | jumla
# Processing Record 11 of Set 11 | sosnovo-ozerskoye
# Processing Record 12 of Set 11 | fairbanks
# Processing Record 13 of Set 11 | juneau
# Processing Record 14 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 11 | san felipe
# Processing Record 16 of Set 11 | seymchan
# Processing Record 17 of Set 11 | katobu
# Processing Record 18 of Set 11 | forrest city
# Processing Record 19 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 11 | sao felix do xingu
# Processing Record 21 of Set 11 | novikovo
# Processing Record 22 of Set 11 | kvitok
# Processing Record 23 of Set 11 | storforshei
# Processing Record 24 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 11 | imbituba
# Processing Record 26 of Set 11 | kintinku
# Processing Record 27 of Set 11 | bichena
# Processing Record 28 of Set 11 | marica
# Processing Record 29 of Set 11 | conakry
# Processing Record 30 of Set 11 | camopi
# Processing Record 31 of Set 11 | zhezkazgan
# Processing Record 32 of Set 11 | erzin
# Processing Record 33 of Set 11 | pointe michel
# Processing Record 34 of Set 11 | namatanai
# Processing Record 35 of Set 11 | anuradhapura
# Processing Record 36 of Set 11 | shenzhen
# Processing Record 37 of Set 11 | zyryanka
# Processing Record 38 of Set 11 | mildura
# Processing Record 39 of Set 11 | pasighat
# Processing Record 40 of Set 11 | mangrol
# Processing Record 41 of Set 11 | verkhnevilyuysk
# Processing Record 42 of Set 11 | kannur
# Processing Record 43 of Set 11 | aktash
# Processing Record 44 of Set 11 | najran
# Processing Record 45 of Set 11 | bousso
# Processing Record 46 of Set 11 | eyl
# Processing Record 47 of Set 11 | huty
# Processing Record 48 of Set 11 | tchibanga
# Processing Record 49 of Set 11 | denpasar
# Processing Record 50 of Set 11 | khasan
# Processing Record 1 of Set 12 | tra vinh
# Processing Record 2 of Set 12 | ballitoville
# Processing Record 3 of Set 12 | valparaiso
# Processing Record 4 of Set 12 | manturovo
# Processing Record 5 of Set 12 | oshkosh
# Processing Record 6 of Set 12 | tigil
# Processing Record 7 of Set 12 | raudeberg
# Processing Record 8 of Set 12 | khatanga
# Processing Record 9 of Set 12 | reconquista
# Processing Record 10 of Set 12 | quatre cocos
# Processing Record 11 of Set 12 | nara
# Processing Record 12 of Set 12 | barsovo
# Processing Record 13 of Set 12 | kupang
# Processing Record 14 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 15 of Set 12 | fortuna
# Processing Record 16 of Set 12 | priiskovyy
# Processing Record 17 of Set 12 | bambanglipuro
# Processing Record 18 of Set 12 | ostrovnoy
# Processing Record 19 of Set 12 | duldurga
# Processing Record 20 of Set 12 | bonavista
# Processing Record 21 of Set 12 | dvinskoy
# Processing Record 22 of Set 12 | smithers
# Processing Record 23 of Set 12 | taganak
# Processing Record 24 of Set 12 | porto velho
# Processing Record 25 of Set 12 | naryan-mar
# Processing Record 26 of Set 12 | ola
# Processing Record 27 of Set 12 | sola
# Processing Record 28 of Set 12 | souillac
# Processing Record 29 of Set 12 | alamosa
# Processing Record 30 of Set 12 | te anau
# Processing Record 31 of Set 12 | broken hill
# Processing Record 32 of Set 12 | embonas
# Processing Record 33 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 34 of Set 12 | roma
# Processing Record 35 of Set 12 | pangnirtung
# Processing Record 36 of Set 12 | mosquera
# Processing Record 37 of Set 12 | cap malheureux
# Processing Record 38 of Set 12 | honningsvag
# Processing Record 39 of Set 12 | tadine
# Processing Record 40 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 12 | nador
# Processing Record 42 of Set 12 | fort-shevchenko
# Processing Record 43 of Set 12 | panchagarh
# Processing Record 44 of Set 12 | ahipara
# Processing Record 45 of Set 12 | kungurtug
# Processing Record 46 of Set 12 | bakuriani
# Processing Record 47 of Set 12 | grand gaube
# Processing Record 48 of Set 12 | vihti
# Processing Record 49 of Set 12 | natal
# Processing Record 50 of Set 12 | moose factory
# Processing Record 1 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 3 of Set 13 | mechanicsville
# Processing Record 4 of Set 13 | nakusp
# Processing Record 5 of Set 13 | mokhotlong
# Processing Record 6 of Set 13 | siachoque
# Processing Record 7 of Set 13 | teahupoo
# Processing Record 8 of Set 13 | jinka
# Processing Record 9 of Set 13 | orlik
# Processing Record 10 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 11 of Set 13 | tabou
# Processing Record 12 of Set 13 | ambon
# Processing Record 13 of Set 13 | karsun
# Processing Record 14 of Set 13 | martapura
# Processing Record 15 of Set 13 | the valley
# Processing Record 16 of Set 13 | barranca
# Processing Record 17 of Set 13 | lupiro
# Processing Record 18 of Set 13 | corinto
# Processing Record 19 of Set 13 | susono
# Processing Record 20 of Set 13 | mana
# Processing Record 21 of Set 13 | rosario do sul
# Processing Record 22 of Set 13 | yaring
# Processing Record 23 of Set 13 | yilan
# Processing Record 24 of Set 13 | teluk nibung
# Processing Record 25 of Set 13 | vossevangen
# Processing Record 26 of Set 13 | soyo
# Processing Record 27 of Set 13 | yermolayevo
# Processing Record 28 of Set 13 | salinopolis
# Processing Record 29 of Set 13 | kunda
# Processing Record 30 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 31 of Set 13 | wanning
# Processing Record 32 of Set 13 | faridpur
# Processing Record 33 of Set 13 | khorramshahr
# Processing Record 34 of Set 13 | benguela
# Processing Record 35 of Set 13 | evensk
# Processing Record 36 of Set 13 | anshun
# Processing Record 37 of Set 13 | shimoda
# Processing Record 38 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 13 | uvalde
# Processing Record 40 of Set 13 | ylivieska
# Processing Record 41 of Set 13 | saint-prosper
# Processing Record 42 of Set 13 | tezu
# Processing Record 43 of Set 13 | samarinda
# Processing Record 44 of Set 13 | tutoia
# Processing Record 45 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 46 of Set 13 | ongandjera
# Processing Record 47 of Set 13 | christchurch
# Processing Record 48 of Set 13 | wad rawah
# Processing Record 49 of Set 13 | sept-iles
# Processing Record 50 of Set 13 | huanuco
# Processing Record 1 of Set 14 | riyadh
# Processing Record 2 of Set 14 | marawi
# Processing Record 3 of Set 14 | camabatela
# Processing Record 4 of Set 14 | nkhata bay
# Processing Record 5 of Set 14 | jackson
# Processing Record 6 of Set 14 | portland
# Processing Record 7 of Set 14 | umm ruwabah
# City not found. Skipping...
# Processing Record 8 of Set 14 | roald
# Processing Record 9 of Set 14 | khandbari
# Processing Record 10 of Set 14 | smirnykh
# Processing Record 11 of Set 14 | monte patria
# Processing Record 12 of Set 14 | long beach
# Processing Record 13 of Set 14 | todos santos
# Processing Record 14 of Set 14 | log
# Processing Record 15 of Set 14 | atmakur
# Processing Record 16 of Set 14 | mogadishu
# Processing Record 17 of Set 14 | bhadrachalam
# Processing Record 18 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 19 of Set 14 | rio grande
# Processing Record 20 of Set 14 | manta
# Processing Record 21 of Set 14 | hearst
# Processing Record 22 of Set 14 | havre-saint-pierre
# Processing Record 23 of Set 14 | tommot
# Processing Record 24 of Set 14 | nizwa
# Processing Record 25 of Set 14 | bucerias
# Processing Record 26 of Set 14 | abonnema
# Processing Record 27 of Set 14 | jutai
# Processing Record 28 of Set 14 | sao jose da coroa grande
# Processing Record 29 of Set 14 | lazaro cardenas
# Processing Record 30 of Set 14 | kurchum
# Processing Record 31 of Set 14 | aksu
# Processing Record 32 of Set 14 | tsiroanomandidy
# Processing Record 33 of Set 14 | bhojudih
# Processing Record 34 of Set 14 | vreed en hoop
# City not found. Skipping...
# Processing Record 35 of Set 14 | ossora
# Processing Record 36 of Set 14 | eisiskes
# Processing Record 37 of Set 14 | gangawati
# Processing Record 38 of Set 14 | tura
# Processing Record 39 of Set 14 | uige
# Processing Record 40 of Set 14 | garissa
# Processing Record 41 of Set 14 | issoudun
# Processing Record 42 of Set 14 | idil
# Processing Record 43 of Set 14 | dolores
# Processing Record 44 of Set 14 | esso
# Processing Record 45 of Set 14 | callaway
# Processing Record 46 of Set 14 | yangambi
# Processing Record 47 of Set 14 | magadan
# Processing Record 48 of Set 14 | inverell
# Processing Record 49 of Set 14 | vagur
# Processing Record 50 of Set 14 | tucurui
# Processing Record 1 of Set 15 | velasco ibarra
# Processing Record 2 of Set 15 | santiago
# Processing Record 3 of Set 15 | wasilla
# Processing Record 4 of Set 15 | rock sound
# Processing Record 5 of Set 15 | riachao do dantas
# Processing Record 6 of Set 15 | frontera
# Processing Record 7 of Set 15 | vanimo
# Processing Record 8 of Set 15 | puerto barrios
# Processing Record 9 of Set 15 | labuan
# Processing Record 10 of Set 15 | aloleng
# Processing Record 11 of Set 15 | mokhsogollokh
# Processing Record 12 of Set 15 | formosa do rio preto
# Processing Record 13 of Set 15 | ati
# Processing Record 14 of Set 15 | tocopilla
# Processing Record 15 of Set 15 | bintulu
# Processing Record 16 of Set 15 | boromo
# Processing Record 17 of Set 15 | umm kaddadah
# Processing Record 18 of Set 15 | kota belud
# Processing Record 19 of Set 15 | haicheng
# Processing Record 20 of Set 15 | darnah
# Processing Record 21 of Set 15 | mandalgovi
# Processing Record 22 of Set 15 | golden
# Processing Record 23 of Set 15 | patacamaya
# Processing Record 24 of Set 15 | ust-shonosha
# Processing Record 25 of Set 15 | nagato
# Processing Record 26 of Set 15 | kirakira
# Processing Record 27 of Set 15 | lubao
# Processing Record 28 of Set 15 | erdenet
# Processing Record 29 of Set 15 | dalbandin
# Processing Record 30 of Set 15 | cayenne
# Processing Record 31 of Set 15 | bukoba
# Processing Record 32 of Set 15 | kimberley
# Processing Record 33 of Set 15 | pitimbu
# Processing Record 34 of Set 15 | joetsu
# Processing Record 35 of Set 15 | teykovo
# Processing Record 36 of Set 15 | tongling
# Processing Record 37 of Set 15 | abalak
# Processing Record 38 of Set 15 | sangar
# Processing Record 39 of Set 15 | montepuez
# Processing Record 40 of Set 15 | bati
# Processing Record 41 of Set 15 | villa carlos paz
# Processing Record 42 of Set 15 | pisco
# Processing Record 43 of Set 15 | missoula
# Processing Record 44 of Set 15 | darhan
# Processing Record 45 of Set 15 | svetlaya
# Processing Record 46 of Set 15 | knin
# Processing Record 47 of Set 15 | tandil
# Processing Record 48 of Set 15 | toowoomba
# Processing Record 49 of Set 15 | vostok
# Processing Record 50 of Set 15 | nacimiento
# Processing Record 1 of Set 16 | naze
# Processing Record 2 of Set 16 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 16 | nanganga
# Processing Record 4 of Set 16 | prince rupert
# Processing Record 5 of Set 16 | nadym
# Processing Record 6 of Set 16 | sterling
# Processing Record 7 of Set 16 | otane
# Processing Record 8 of Set 16 | pedasi
# Processing Record 9 of Set 16 | fethiye
# Processing Record 10 of Set 16 | yashkul
# Processing Record 11 of Set 16 | amalner
# Processing Record 12 of Set 16 | narsaq
# Processing Record 13 of Set 16 | talcahuano
# Processing Record 14 of Set 16 | casper
# Processing Record 15 of Set 16 | mehamn
# Processing Record 16 of Set 16 | vestmanna
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Gasa',
#   'Country': 'PS',
#   'Lat': 31.5,
#   'Lng': 34.4667,
#   'Max Temp': 76.98,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 7.94,
#   'Current Description': 'clear sky'},
#  {'City': 'Bulungu',
#   'Country': 'CD',
#   'Lat': -4.55,
#   'Lng': 18.6,
#   'Max Temp': 70.21,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 1.59,
#   'Current Description': 'light rain'},
#  {'City': 'Wakkanai',
#   'Country': 'JP',
#   'Lat': 45.4094,
#   'Lng': 141.6739,
#   'Max Temp': 67.98,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 41.11,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 69.22,
#   'Humidity': 90,
#   'Cloudiness': 87,
#   'Wind Speed': 6.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 38.86,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 1.14,
#   'Current Description': 'clear sky'},
#  {'City': 'Salalah',
#   'Country': 'OM',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 80.69,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 1.14,
#   'Current Description': 'few clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 47.88,
#   'Humidity': 98,
#   'Cloudiness': 72,
#   'Wind Speed': 3.94,
#   'Current Description': 'broken clouds'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 60.12,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Ampanihy',
#   'Country': 'MG',
#   'Lat': -24.7,
#   'Lng': 44.75,
#   'Max Temp': 68.18,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 5.32,
#   'Current Description': 'clear sky'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 60.64,
#   'Humidity': 83,
#   'Cloudiness': 82,
#   'Wind Speed': 13.15,
#   'Current Description': 'light rain'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 58.75,
#   'Humidity': 35,
#   'Cloudiness': 50,
#   'Wind Speed': 4.25,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 55.8,
#   'Humidity': 54,
#   'Cloudiness': 5,
#   'Wind Speed': 6.73,
#   'Current Description': 'clear sky'},
#  {'City': 'Toamasina',
#   'Country': 'MG',
#   'Lat': -18.1667,
#   'Lng': 49.3833,
#   'Max Temp': 66.2,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Current Description': 'light rain'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 78.85,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Current Description': 'few clouds'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 83.71,
#   'Humidity': 73,
#   'Cloudiness': 91,
#   'Wind Speed': 13.91,
#   'Current Description': 'light rain'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 55.54,
#   'Humidity': 87,
#   'Cloudiness': 6,
#   'Wind Speed': 5.21,
#   'Current Description': 'clear sky'},
#  {'City': 'Tessalit',
#   'Country': 'ML',
#   'Lat': 20.1986,
#   'Lng': 1.0114,
#   'Max Temp': 84.72,
#   'Humidity': 16,
#   'Cloudiness': 1,
#   'Wind Speed': 8.14,
#   'Current Description': 'clear sky'},
#  {'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 35.44,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 21.85,
#   'Current Description': 'light rain'},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 57.18,
#   'Humidity': 94,
#   'Cloudiness': 55,
#   'Wind Speed': 16.93,
#   'Current Description': 'broken clouds'},
#  {'City': 'Beringovskiy',
#   'Country': 'RU',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 36.73,
#   'Humidity': 87,
#   'Cloudiness': 92,
#   'Wind Speed': 3.42,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 70.72,
#   'Humidity': 66,
#   'Cloudiness': 17,
#   'Wind Speed': 3.31,
#   'Current Description': 'few clouds'},
#  {'City': 'Cabo San Lucas',
#   'Country': 'MX',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 86.61,
#   'Humidity': 76,
#   'Cloudiness': 6,
#   'Wind Speed': 5.28,
#   'Current Description': 'clear sky'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 63.72,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 1.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Santo Anastacio',
#   'Country': 'BR',
#   'Lat': -21.8383,
#   'Lng': -51.6103,
#   'Max Temp': 73.76,
#   'Humidity': 59,
#   'Cloudiness': 75,
#   'Wind Speed': 7.94,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sao Filipe',
#   'Country': 'CV',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 78.4,
#   'Humidity': 81,
#   'Cloudiness': 79,
#   'Wind Speed': 5.53,
#   'Current Description': 'broken clouds'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 23.02,
#   'Humidity': 80,
#   'Cloudiness': 1,
#   'Wind Speed': 14.97,
#   'Current Description': 'clear sky'},
#  {'City': 'Beyneu',
#   'Country': 'KZ',
#   'Lat': 45.3167,
#   'Lng': 55.2,
#   'Max Temp': 61.3,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 24.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 59.11,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 4,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 19.8,
#   'Humidity': 59,
#   'Cloudiness': 85,
#   'Wind Speed': 8.52,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Newport',
#   'Country': 'GB',
#   'Lat': 51.5877,
#   'Lng': -2.9984,
#   'Max Temp': 64.94,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 28.14,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kloulklubed',
#   'Country': 'PW',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 86.5,
#   'Humidity': 74,
#   'Cloudiness': 84,
#   'Wind Speed': 7.94,
#   'Current Description': 'broken clouds'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 35.53,
#   'Humidity': 86,
#   'Cloudiness': 76,
#   'Wind Speed': 24.67,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mount Gambier',
#   'Country': 'AU',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 66.11,
#   'Humidity': 34,
#   'Cloudiness': 76,
#   'Wind Speed': 12.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Havelock',
#   'Country': 'US',
#   'Lat': 34.8791,
#   'Lng': -76.9013,
#   'Max Temp': 69.75,
#   'Humidity': 88,
#   'Cloudiness': 3,
#   'Wind Speed': 1.79,
#   'Current Description': 'clear sky'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 73.65,
#   'Humidity': 72,
#   'Cloudiness': 33,
#   'Wind Speed': 19.6,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 35.24,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 13.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kahului',
#   'Country': 'US',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 83.46,
#   'Humidity': 85,
#   'Cloudiness': 40,
#   'Wind Speed': 20.71,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Murray Bridge',
#   'Country': 'AU',
#   'Lat': -35.1167,
#   'Lng': 139.2667,
#   'Max Temp': 75.49,
#   'Humidity': 23,
#   'Cloudiness': 56,
#   'Wind Speed': 12.73,
#   'Current Description': 'broken clouds'},
#  {'City': 'Rawson',
#   'Country': 'AR',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 51.01,
#   'Humidity': 31,
#   'Cloudiness': 5,
#   'Wind Speed': 8.55,
#   'Current Description': 'clear sky'},
#  {'City': 'Margate',
#   'Country': 'GB',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 64.11,
#   'Humidity': 98,
#   'Cloudiness': 89,
#   'Wind Speed': 15.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Skibbereen',
#   'Country': 'IE',
#   'Lat': 51.55,
#   'Lng': -9.2667,
#   'Max Temp': 51.6,
#   'Humidity': 82,
#   'Cloudiness': 71,
#   'Wind Speed': 15.43,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 82.85,
#   'Humidity': 71,
#   'Cloudiness': 74,
#   'Wind Speed': 3.76,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vao',
#   'Country': 'NC',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 68.27,
#   'Humidity': 68,
#   'Cloudiness': 35,
#   'Wind Speed': 10.87,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Marktheidenfeld',
#   'Country': 'DE',
#   'Lat': 49.8442,
#   'Lng': 9.6039,
#   'Max Temp': 62.53,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 80.33,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Current Description': 'moderate rain'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 63.09,
#   'Humidity': 75,
#   'Cloudiness': 64,
#   'Wind Speed': 12.41,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 84.18,
#   'Humidity': 75,
#   'Cloudiness': 40,
#   'Wind Speed': 1.99,
#   'Current Description': 'light rain'},
#  {'City': 'Wattegama',
#   'Country': 'LK',
#   'Lat': 6.7989,
#   'Lng': 81.4808,
#   'Max Temp': 79.72,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 14.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ojuelos De Jalisco',
#   'Country': 'MX',
#   'Lat': 21.8667,
#   'Lng': -101.5833,
#   'Max Temp': 61.74,
#   'Humidity': 71,
#   'Cloudiness': 87,
#   'Wind Speed': 8.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zaysan',
#   'Country': 'KZ',
#   'Lat': 47.4667,
#   'Lng': 84.8667,
#   'Max Temp': 47.64,
#   'Humidity': 44,
#   'Cloudiness': 60,
#   'Wind Speed': 3.2,
#   'Current Description': 'broken clouds'},
#  {'City': 'Faanui',
#   'Country': 'PF',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 79.66,
#   'Humidity': 73,
#   'Cloudiness': 2,
#   'Wind Speed': 11.83,
#   'Current Description': 'clear sky'},
#  {'City': 'Klaksvik',
#   'Country': 'FO',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 49.12,
#   'Humidity': 86,
#   'Cloudiness': 91,
#   'Wind Speed': 14.07,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Baquerizo Moreno',
#   'Country': 'EC',
#   'Lat': -0.9,
#   'Lng': -89.6,
#   'Max Temp': 68.56,
#   'Humidity': 90,
#   'Cloudiness': 29,
#   'Wind Speed': 9.35,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 45.36,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 9.71,
#   'Current Description': 'clear sky'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 78.08,
#   'Humidity': 73,
#   'Cloudiness': 5,
#   'Wind Speed': 18.81,
#   'Current Description': 'clear sky'},
#  {'City': 'Jiwani',
#   'Country': 'PK',
#   'Lat': 25.05,
#   'Lng': 61.7417,
#   'Max Temp': 81.46,
#   'Humidity': 79,
#   'Cloudiness': 36,
#   'Wind Speed': 3.65,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Burnie',
#   'Country': 'AU',
#   'Lat': -41.0667,
#   'Lng': 145.9167,
#   'Max Temp': 53.06,
#   'Humidity': 66,
#   'Cloudiness': 99,
#   'Wind Speed': 3.56,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pirogovo',
#   'Country': 'RU',
#   'Lat': 56.7796,
#   'Lng': 53.1495,
#   'Max Temp': 39.65,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 16.31,
#   'Current Description': 'moderate rain'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 15.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chernyshevskiy',
#   'Country': 'RU',
#   'Lat': 63.0128,
#   'Lng': 112.4714,
#   'Max Temp': 35.51,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 15.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hambantota',
#   'Country': 'LK',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 80.94,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Hardy',
#   'Country': 'CA',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 57.2,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 23.02,
#   'Current Description': 'light intensity shower rain'},
#  {'City': 'Padang',
#   'Country': 'ID',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 78.85,
#   'Humidity': 84,
#   'Cloudiness': 96,
#   'Wind Speed': 5.14,
#   'Current Description': 'light rain'},
#  {'City': 'Jalu',
#   'Country': 'LY',
#   'Lat': 29.0331,
#   'Lng': 21.5482,
#   'Max Temp': 69.06,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 9.19,
#   'Current Description': 'clear sky'},
#  {'City': 'Mount Darwin',
#   'Country': 'ZW',
#   'Lat': -16.7725,
#   'Lng': 31.5838,
#   'Max Temp': 61.05,
#   'Humidity': 67,
#   'Cloudiness': 6,
#   'Wind Speed': 5.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 69.39,
#   'Humidity': 87,
#   'Cloudiness': 83,
#   'Wind Speed': 16.04,
#   'Current Description': 'light rain'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 55.47,
#   'Humidity': 34,
#   'Cloudiness': 4,
#   'Wind Speed': 2.06,
#   'Current Description': 'clear sky'},
#  {'City': 'Alyangula',
#   'Country': 'AU',
#   'Lat': -13.8483,
#   'Lng': 136.4192,
#   'Max Temp': 85.87,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Egvekinot',
#   'Country': 'RU',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': 26.13,
#   'Humidity': 74,
#   'Cloudiness': 10,
#   'Wind Speed': 3.49,
#   'Current Description': 'clear sky'},
#  {'City': 'Buraydah',
#   'Country': 'SA',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp': 70.25,
#   'Humidity': 34,
#   'Cloudiness': 38,
#   'Wind Speed': 4.41,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 32.16,
#   'Humidity': 63,
#   'Cloudiness': 16,
#   'Wind Speed': 6.62,
#   'Current Description': 'few clouds'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 69.87,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Turkistan',
#   'Country': 'KZ',
#   'Lat': 43,
#   'Lng': 68,
#   'Max Temp': 58.33,
#   'Humidity': 62,
#   'Cloudiness': 74,
#   'Wind Speed': 18.07,
#   'Current Description': 'broken clouds'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 88.25,
#   'Humidity': 72,
#   'Cloudiness': 28,
#   'Wind Speed': 1.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hami',
#   'Country': 'CN',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 70.11,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 3.4,
#   'Current Description': 'clear sky'},
#  {'City': 'Deputatskiy',
#   'Country': 'RU',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': 27.7,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 13.58,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Helena',
#   'Country': 'US',
#   'Lat': 46.5927,
#   'Lng': -112.0361,
#   'Max Temp': 70.79,
#   'Humidity': 29,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Koksovyy',
#   'Country': 'RU',
#   'Lat': 48.1967,
#   'Lng': 40.5989,
#   'Max Temp': 46.63,
#   'Humidity': 87,
#   'Cloudiness': 7,
#   'Wind Speed': 12.88,
#   'Current Description': 'clear sky'},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 55.49,
#   'Humidity': 94,
#   'Cloudiness': 7,
#   'Wind Speed': 4.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Neuquen',
#   'Country': 'AR',
#   'Lat': -38.9516,
#   'Lng': -68.0591,
#   'Max Temp': 49.89,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Current Description': 'clear sky'},
#  {'City': 'Northam',
#   'Country': 'GB',
#   'Lat': 51.0333,
#   'Lng': -4.2167,
#   'Max Temp': 63.39,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 25.01,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Meulaboh',
#   'Country': 'ID',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 79.95,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 1.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Goderich',
#   'Country': 'CA',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 61.12,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Medina Del Campo',
#   'Country': 'ES',
#   'Lat': 41.3124,
#   'Lng': -4.9141,
#   'Max Temp': 61.75,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 7.58,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Charters Towers',
#   'Country': 'AU',
#   'Lat': -20.1,
#   'Lng': 146.2667,
#   'Max Temp': 88.11,
#   'Humidity': 24,
#   'Cloudiness': 2,
#   'Wind Speed': 11.81,
#   'Current Description': 'clear sky'},
#  {'City': 'Chokwe',
#   'Country': 'MZ',
#   'Lat': -24.5333,
#   'Lng': 32.9833,
#   'Max Temp': 67.89,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 3.85,
#   'Current Description': 'clear sky'},
#  {'City': 'Sisophon',
#   'Country': 'KH',
#   'Lat': 13.5859,
#   'Lng': 102.9737,
#   'Max Temp': 84.07,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 4.09,
#   'Current Description': 'light rain'},
#  {'City': 'Doctor Juan Leon Mallorquin',
#   'Country': 'PY',
#   'Lat': -25.4,
#   'Lng': -55.2667,
#   'Max Temp': 74.93,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 3.62,
#   'Current Description': 'clear sky'},
#  {'City': 'Berberati',
#   'Country': 'CF',
#   'Lat': 4.2612,
#   'Lng': 15.7922,
#   'Max Temp': 67.53,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.52,
#   'Current Description': 'moderate rain'},
#  {'City': 'Markova',
#   'Country': 'UA',
#   'Lat': 48.6758,
#   'Lng': 24.4138,
#   'Max Temp': 52.32,
#   'Humidity': 93,
#   'Cloudiness': 68,
#   'Wind Speed': 2.26,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lebork',
#   'Country': 'PL',
#   'Lat': 54.5392,
#   'Lng': 17.7501,
#   'Max Temp': 51.93,
#   'Humidity': 71,
#   'Cloudiness': 54,
#   'Wind Speed': 9.86,
#   'Current Description': 'broken clouds'},
#  {'City': 'Grand-Santi',
#   'Country': 'GF',
#   'Lat': 4.25,
#   'Lng': -54.3833,
#   'Max Temp': 71.51,
#   'Humidity': 98,
#   'Cloudiness': 27,
#   'Wind Speed': 2.86,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hovin',
#   'Country': 'NO',
#   'Lat': 63.1055,
#   'Lng': 10.225,
#   'Max Temp': 60.13,
#   'Humidity': 85,
#   'Cloudiness': 76,
#   'Wind Speed': 8.28,
#   'Current Description': 'broken clouds'},
#  {'City': 'Yulara',
#   'Country': 'AU',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 87.64,
#   'Humidity': 8,
#   'Cloudiness': 95,
#   'Wind Speed': 16.11,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 32,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Current Description': 'broken clouds'},
#  {'City': 'Half Moon Bay',
#   'Country': 'US',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp': 64.29,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Oshnaviyeh',
#   'Country': 'IR',
#   'Lat': 37.0397,
#   'Lng': 45.0983,
#   'Max Temp': 43.05,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 0.2,
#   'Current Description': 'clear sky'},
#  {'City': 'Baykit',
#   'Country': 'RU',
#   'Lat': 61.67,
#   'Lng': 96.37,
#   'Max Temp': 38.77,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 10.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Baripada',
#   'Country': 'IN',
#   'Lat': 21.935,
#   'Lng': 86.7214,
#   'Max Temp': 83.53,
#   'Humidity': 81,
#   'Cloudiness': 35,
#   'Wind Speed': 8.3,
#   'Current Description': 'light rain'},
#  {'City': 'Douentza',
#   'Country': 'ML',
#   'Lat': 14.9951,
#   'Lng': -2.9517,
#   'Max Temp': 91.04,
#   'Humidity': 27,
#   'Cloudiness': 88,
#   'Wind Speed': 3.24,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Boddam',
#   'Country': 'GB',
#   'Lat': 57.4667,
#   'Lng': -1.7833,
#   'Max Temp': 58.08,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 14.47,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Boyolangu',
#   'Country': 'ID',
#   'Lat': -8.1181,
#   'Lng': 111.8935,
#   'Max Temp': 83.23,
#   'Humidity': 64,
#   'Cloudiness': 62,
#   'Wind Speed': 12.37,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vila Velha',
#   'Country': 'BR',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 73.35,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Codrington',
#   'Country': 'AU',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 64.2,
#   'Humidity': 53,
#   'Cloudiness': 13,
#   'Wind Speed': 12.41,
#   'Current Description': 'few clouds'},
#  {'City': 'Olafsvik',
#   'Country': 'IS',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 38.43,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 28.88,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 50.94,
#   'Humidity': 52,
#   'Cloudiness': 5,
#   'Wind Speed': 8.03,
#   'Current Description': 'clear sky'},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 76.1,
#   'Humidity': 84,
#   'Cloudiness': 59,
#   'Wind Speed': 13.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Takapau',
#   'Country': 'NZ',
#   'Lat': -40.0333,
#   'Lng': 176.35,
#   'Max Temp': 51.19,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 4.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 42.57,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Current Description': 'few clouds'},
#  {'City': 'Grindavik',
#   'Country': 'IS',
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp': 39.67,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 29.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 68.34,
#   'Humidity': 73,
#   'Cloudiness': 73,
#   'Wind Speed': 21.7,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bethal',
#   'Country': 'ZA',
#   'Lat': -26.4579,
#   'Lng': 29.4655,
#   'Max Temp': 53.55,
#   'Humidity': 46,
#   'Cloudiness': 6,
#   'Wind Speed': 4.27,
#   'Current Description': 'clear sky'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 77.16,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Taksimo',
#   'Country': 'RU',
#   'Lat': 56.3444,
#   'Lng': 114.8794,
#   'Max Temp': 38.35,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Current Description': 'light rain'},
#  {'City': 'Atar',
#   'Country': 'MR',
#   'Lat': 20.5169,
#   'Lng': -13.0499,
#   'Max Temp': 92.21,
#   'Humidity': 16,
#   'Cloudiness': 4,
#   'Wind Speed': 6.67,
#   'Current Description': 'clear sky'},
#  {'City': 'Placido De Castro',
#   'Country': 'BR',
#   'Lat': -10.3353,
#   'Lng': -67.1856,
#   'Max Temp': 80.51,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 3.62,
#   'Current Description': 'clear sky'},
#  {'City': 'Palmas',
#   'Country': 'BR',
#   'Lat': -10.2128,
#   'Lng': -48.3603,
#   'Max Temp': 71.47,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Banda Aceh',
#   'Country': 'ID',
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Max Temp': 85.03,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 11.95,
#   'Current Description': 'moderate rain'},
#  {'City': 'Dunedin',
#   'Country': 'NZ',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 48.52,
#   'Humidity': 60,
#   'Cloudiness': 49,
#   'Wind Speed': 13.87,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tornio',
#   'Country': 'FI',
#   'Lat': 65.8481,
#   'Lng': 24.1466,
#   'Max Temp': 46.42,
#   'Humidity': 94,
#   'Cloudiness': 71,
#   'Wind Speed': 10.89,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ust-Tsilma',
#   'Country': 'RU',
#   'Lat': 65.441,
#   'Lng': 52.1498,
#   'Max Temp': 38.5,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 5.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Itororo',
#   'Country': 'BR',
#   'Lat': -15.1169,
#   'Lng': -40.0703,
#   'Max Temp': 66.88,
#   'Humidity': 95,
#   'Cloudiness': 89,
#   'Wind Speed': 1.86,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Muros',
#   'Country': 'ES',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 68.23,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 13.47,
#   'Current Description': 'light rain'},
#  {'City': 'Poum',
#   'Country': 'NC',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 72.59,
#   'Humidity': 63,
#   'Cloudiness': 8,
#   'Wind Speed': 7.58,
#   'Current Description': 'clear sky'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 84.94,
#   'Humidity': 27,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 55.45,
#   'Humidity': 89,
#   'Cloudiness': 3,
#   'Wind Speed': 14.88,
#   'Current Description': 'clear sky'},
#  {'City': 'Berlevag',
#   'Country': 'NO',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 50,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 19.3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dwarka',
#   'Country': 'IN',
#   'Lat': 22.2394,
#   'Lng': 68.9678,
#   'Max Temp': 82.15,
#   'Humidity': 81,
#   'Cloudiness': 89,
#   'Wind Speed': 4.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 64.24,
#   'Humidity': 88,
#   'Cloudiness': 33,
#   'Wind Speed': 20.24,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Guerrero Negro',
#   'Country': 'MX',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 69.57,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 18.79,
#   'Current Description': 'clear sky'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 47.62,
#   'Humidity': 77,
#   'Cloudiness': 3,
#   'Wind Speed': 18.68,
#   'Current Description': 'clear sky'},
#  {'City': 'Cochrane',
#   'Country': 'CA',
#   'Lat': 51.1834,
#   'Lng': -114.4687,
#   'Max Temp': 65.48,
#   'Humidity': 38,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sabang',
#   'Country': 'ID',
#   'Lat': 5.8933,
#   'Lng': 95.3214,
#   'Max Temp': 81.72,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 18.14,
#   'Current Description': 'moderate rain'},
#  {'City': 'Budureasa',
#   'Country': 'RO',
#   'Lat': 46.6667,
#   'Lng': 22.5,
#   'Max Temp': 54.01,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 5.77,
#   'Current Description': 'clear sky'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 23.67,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Current Description': 'clear sky'},
#  {'City': 'Calama',
#   'Country': 'CL',
#   'Lat': -22.4667,
#   'Lng': -68.9333,
#   'Max Temp': 58.8,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 7.65,
#   'Current Description': 'clear sky'},
#  {'City': 'Aleksandrovskiy Zavod',
#   'Country': 'RU',
#   'Lat': 50.9237,
#   'Lng': 117.9374,
#   'Max Temp': 45.28,
#   'Humidity': 48,
#   'Cloudiness': 3,
#   'Wind Speed': 19.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Beloha',
#   'Country': 'MG',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 67.57,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 7.74,
#   'Current Description': 'clear sky'},
#  {'City': 'Acapulco',
#   'Country': 'MX',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 80.8,
#   'Humidity': 82,
#   'Cloudiness': 96,
#   'Wind Speed': 4.12,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 71.22,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Current Description': 'broken clouds'},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 28.92,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 17.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lavrentiya',
#   'Country': 'RU',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 33.04,
#   'Humidity': 82,
#   'Cloudiness': 68,
#   'Wind Speed': 3.42,
#   'Current Description': 'broken clouds'},
#  {'City': 'Povenets',
#   'Country': 'RU',
#   'Lat': 62.8487,
#   'Lng': 34.8262,
#   'Max Temp': 45.52,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 5.3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Makakilo City',
#   'Country': 'US',
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp': 86.32,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Current Description': 'few clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 71.08,
#   'Humidity': 87,
#   'Cloudiness': 86,
#   'Wind Speed': 22.15,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Panaba',
#   'Country': 'MX',
#   'Lat': 21.2833,
#   'Lng': -88.2667,
#   'Max Temp': 76.86,
#   'Humidity': 87,
#   'Cloudiness': 37,
#   'Wind Speed': 7.49,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Maicao',
#   'Country': 'CO',
#   'Lat': 11.3832,
#   'Lng': -72.2432,
#   'Max Temp': 82.08,
#   'Humidity': 81,
#   'Cloudiness': 85,
#   'Wind Speed': 11.39,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Skjervoy',
#   'Country': 'NO',
#   'Lat': 70.0311,
#   'Lng': 20.9714,
#   'Max Temp': 51.8,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 4.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 57.9,
#   'Humidity': 90,
#   'Cloudiness': 45,
#   'Wind Speed': 2.64,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Clinton',
#   'Country': 'US',
#   'Lat': 42.587,
#   'Lng': -82.9199,
#   'Max Temp': 69.1,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Puerto Narino',
#   'Country': 'CO',
#   'Lat': -3.7703,
#   'Lng': -70.3831,
#   'Max Temp': 75.15,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 83.8,
#   'Humidity': 73,
#   'Cloudiness': 35,
#   'Wind Speed': 8.79,
#   'Current Description': 'light rain'},
#  {'City': 'Khash',
#   'Country': 'IR',
#   'Lat': 28.2211,
#   'Lng': 61.2158,
#   'Max Temp': 73.98,
#   'Humidity': 12,
#   'Cloudiness': 9,
#   'Wind Speed': 5.66,
#   'Current Description': 'clear sky'},
#  {'City': 'Coquimbo',
#   'Country': 'CL',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 55.13,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Avera',
#   'Country': 'US',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 66.7,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 3.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Karangasem',
#   'Country': 'ID',
#   'Lat': -8.45,
#   'Lng': 115.6167,
#   'Max Temp': 81.48,
#   'Humidity': 63,
#   'Cloudiness': 82,
#   'Wind Speed': 10.02,
#   'Current Description': 'broken clouds'},
#  {'City': 'Talara',
#   'Country': 'PE',
#   'Lat': -4.5772,
#   'Lng': -81.2719,
#   'Max Temp': 65.21,
#   'Humidity': 88,
#   'Cloudiness': 34,
#   'Wind Speed': 11.68,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Qostanay',
#   'Country': 'KZ',
#   'Lat': 53.1667,
#   'Lng': 63.5833,
#   'Max Temp': 43.09,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 20.13,
#   'Current Description': 'clear sky'},
#  {'City': 'Innisfail',
#   'Country': 'AU',
#   'Lat': -17.5333,
#   'Lng': 146.0333,
#   'Max Temp': 89.87,
#   'Humidity': 60,
#   'Cloudiness': 11,
#   'Wind Speed': 8.79,
#   'Current Description': 'few clouds'},
#  {'City': 'Yarada',
#   'Country': 'IN',
#   'Lat': 17.65,
#   'Lng': 83.2667,
#   'Max Temp': 81.14,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 15.61,
#   'Current Description': 'moderate rain'},
#  {'City': 'San Lorenzo',
#   'Country': 'PY',
#   'Lat': -25.3333,
#   'Lng': -57.5333,
#   'Max Temp': 76.59,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 7,
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Escondido',
#   'Country': 'MX',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 81.21,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 3.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Isla Mujeres',
#   'Country': 'MX',
#   'Lat': 21.2311,
#   'Lng': -86.731,
#   'Max Temp': 82.45,
#   'Humidity': 78,
#   'Cloudiness': 12,
#   'Wind Speed': 8.48,
#   'Current Description': 'few clouds'},
#  {'City': 'Lang Son',
#   'Country': 'VN',
#   'Lat': 21.8333,
#   'Lng': 106.7333,
#   'Max Temp': 84.15,
#   'Humidity': 69,
#   'Cloudiness': 22,
#   'Wind Speed': 1.72,
#   'Current Description': 'few clouds'},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 25.99,
#   'Humidity': 87,
#   'Cloudiness': 32,
#   'Wind Speed': 9.46,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 27.19,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 19.39,
#   'Current Description': 'light snow'},
#  {'City': 'Sal Rei',
#   'Country': 'CV',
#   'Lat': 16.1833,
#   'Lng': -22.9167,
#   'Max Temp': 79.36,
#   'Humidity': 82,
#   'Cloudiness': 32,
#   'Wind Speed': 10.85,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Katherine',
#   'Country': 'AU',
#   'Lat': -14.4667,
#   'Lng': 132.2667,
#   'Max Temp': 93.52,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Binga',
#   'Country': 'ZW',
#   'Lat': -17.6203,
#   'Lng': 27.3414,
#   'Max Temp': 68.2,
#   'Humidity': 38,
#   'Cloudiness': 10,
#   'Wind Speed': 1.95,
#   'Current Description': 'clear sky'},
#  {'City': 'Caravelas',
#   'Country': 'BR',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 71.73,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 6.87,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vytegra',
#   'Country': 'RU',
#   'Lat': 61.0064,
#   'Lng': 36.4481,
#   'Max Temp': 42.31,
#   'Humidity': 94,
#   'Cloudiness': 59,
#   'Wind Speed': 3.47,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tual',
#   'Country': 'ID',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 80.85,
#   'Humidity': 82,
#   'Cloudiness': 84,
#   'Wind Speed': 12.39,
#   'Current Description': 'broken clouds'},
#  {'City': 'Barmer',
#   'Country': 'IN',
#   'Lat': 25.75,
#   'Lng': 71.3833,
#   'Max Temp': 86.88,
#   'Humidity': 62,
#   'Cloudiness': 15,
#   'Wind Speed': 4.94,
#   'Current Description': 'few clouds'},
#  {'City': 'Sinjar',
#   'Country': 'IQ',
#   'Lat': 36.3209,
#   'Lng': 41.8754,
#   'Max Temp': 68.65,
#   'Humidity': 19,
#   'Cloudiness': 4,
#   'Wind Speed': 4.45,
#   'Current Description': 'clear sky'},
#  {'City': 'Fukue',
#   'Country': 'JP',
#   'Lat': 32.6881,
#   'Lng': 128.8419,
#   'Max Temp': 79.16,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lorengau',
#   'Country': 'PG',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 81.86,
#   'Humidity': 79,
#   'Cloudiness': 95,
#   'Wind Speed': 6.24,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zalantun',
#   'Country': 'CN',
#   'Lat': 48,
#   'Lng': 122.7167,
#   'Max Temp': 60.84,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 14.76,
#   'Current Description': 'clear sky'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 53.1,
#   'Humidity': 66,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Manono',
#   'Country': 'CD',
#   'Lat': -7.3,
#   'Lng': 27.4167,
#   'Max Temp': 71.42,
#   'Humidity': 68,
#   'Cloudiness': 87,
#   'Wind Speed': 2.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 66.04,
#   'Humidity': 80,
#   'Cloudiness': 80,
#   'Wind Speed': 18.12,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kathu',
#   'Country': 'TH',
#   'Lat': 7.9178,
#   'Lng': 98.3332,
#   'Max Temp': 80.42,
#   'Humidity': 76,
#   'Cloudiness': 94,
#   'Wind Speed': 1.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ust-Maya',
#   'Country': 'RU',
#   'Lat': 60.4167,
#   'Lng': 134.5333,
#   'Max Temp': 45.54,
#   'Humidity': 54,
#   'Cloudiness': 97,
#   'Wind Speed': 7.67,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Grenada',
#   'Country': 'ES',
#   'Lat': 37.1882,
#   'Lng': -3.6067,
#   'Max Temp': 67.12,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Hamilton',
#   'Country': 'US',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 63.84,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Rincon',
#   'Country': 'US',
#   'Lat': 32.296,
#   'Lng': -81.2354,
#   'Max Temp': 73.85,
#   'Humidity': 87,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Inuvik',
#   'Country': 'CA',
#   'Lat': 68.3499,
#   'Lng': -133.7218,
#   'Max Temp': 32.86,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14,
#   'Current Description': 'broken clouds'},
#  {'City': 'Husavik',
#   'Country': 'IS',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 33.71,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 26.49,
#   'Current Description': 'snow'},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 80.33,
#   'Humidity': 31,
#   'Cloudiness': 55,
#   'Wind Speed': 3.53,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 34.39,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 12.08,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Belmonte',
#   'Country': 'BR',
#   'Lat': -15.8631,
#   'Lng': -38.8828,
#   'Max Temp': 73.9,
#   'Humidity': 89,
#   'Cloudiness': 77,
#   'Wind Speed': 6.78,
#   'Current Description': 'broken clouds'},
#  {'City': 'Harper',
#   'Country': 'LR',
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp': 75.4,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.88,
#   'Current Description': 'light rain'},
#  {'City': 'Mansehra',
#   'Country': 'PK',
#   'Lat': 34.3333,
#   'Lng': 73.2,
#   'Max Temp': 73.44,
#   'Humidity': 66,
#   'Cloudiness': 12,
#   'Wind Speed': 2.24,
#   'Current Description': 'few clouds'},
#  {'City': 'Taraz',
#   'Country': 'KZ',
#   'Lat': 42.9,
#   'Lng': 71.3667,
#   'Max Temp': 68.41,
#   'Humidity': 28,
#   'Cloudiness': 40,
#   'Wind Speed': 22.37,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Neka',
#   'Country': 'IR',
#   'Lat': 36.6508,
#   'Lng': 53.299,
#   'Max Temp': 61.65,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 4.9,
#   'Current Description': 'clear sky'},
#  {'City': 'Kaeo',
#   'Country': 'NZ',
#   'Lat': -35.1,
#   'Lng': 173.7833,
#   'Max Temp': 51.96,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Keetmanshoop',
#   'Country': 'NA',
#   'Lat': -26.5833,
#   'Lng': 18.1333,
#   'Max Temp': 72.52,
#   'Humidity': 17,
#   'Cloudiness': 58,
#   'Wind Speed': 5.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Acarau',
#   'Country': 'BR',
#   'Lat': -2.8856,
#   'Lng': -40.12,
#   'Max Temp': 78.98,
#   'Humidity': 84,
#   'Cloudiness': 12,
#   'Wind Speed': 18.45,
#   'Current Description': 'few clouds'},
#  {'City': 'Sigli',
#   'Country': 'ID',
#   'Lat': 5.3848,
#   'Lng': 95.9609,
#   'Max Temp': 84.56,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 4.21,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nizhneangarsk',
#   'Country': 'RU',
#   'Lat': 55.7833,
#   'Lng': 109.55,
#   'Max Temp': 38.71,
#   'Humidity': 53,
#   'Cloudiness': 78,
#   'Wind Speed': 3.94,
#   'Current Description': 'broken clouds'},
#  {'City': 'Prachuap Khiri Khan',
#   'Country': 'TH',
#   'Lat': 12.2167,
#   'Lng': 99.75,
#   'Max Temp': 80.91,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 1.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 46.56,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Current Description': 'few clouds'},
#  {'City': 'San Jose',
#   'Country': 'US',
#   'Lat': 37.3394,
#   'Lng': -121.895,
#   'Max Temp': 65.3,
#   'Humidity': 75,
#   'Cloudiness': 40,
#   'Wind Speed': 5.01,
#   'Current Description': 'smoke'},
#  {'City': 'Mittersill',
#   'Country': 'AT',
#   'Lat': 47.2667,
#   'Lng': 12.4833,
#   'Max Temp': 60.13,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 30.24,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hofn',
#   'Country': 'IS',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 42.51,
#   'Humidity': 61,
#   'Cloudiness': 92,
#   'Wind Speed': 9.86,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Buta',
#   'Country': 'CD',
#   'Lat': 2.7858,
#   'Lng': 24.73,
#   'Max Temp': 66.58,
#   'Humidity': 99,
#   'Cloudiness': 89,
#   'Wind Speed': 1.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Oranjemund',
#   'Country': 'NA',
#   'Lat': -28.55,
#   'Lng': 16.4333,
#   'Max Temp': 58.03,
#   'Humidity': 89,
#   'Cloudiness': 89,
#   'Wind Speed': 10.07,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 56.52,
#   'Humidity': 88,
#   'Cloudiness': 39,
#   'Wind Speed': 1.14,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nantucket',
#   'Country': 'US',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 66.09,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Raahe',
#   'Country': 'FI',
#   'Lat': 64.6833,
#   'Lng': 24.4833,
#   'Max Temp': 39.29,
#   'Humidity': 81,
#   'Cloudiness': 76,
#   'Wind Speed': 12.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint-Louis',
#   'Country': 'SN',
#   'Lat': 16.3333,
#   'Lng': -15,
#   'Max Temp': 83.07,
#   'Humidity': 59,
#   'Cloudiness': 89,
#   'Wind Speed': 10.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mwinilunga',
#   'Country': 'ZM',
#   'Lat': -11.7358,
#   'Lng': 24.4293,
#   'Max Temp': 67.03,
#   'Humidity': 37,
#   'Cloudiness': 81,
#   'Wind Speed': 0.67,
#   'Current Description': 'broken clouds'},
#  {'City': 'Puerto Leguizamo',
#   'Country': 'CO',
#   'Lat': -0.1934,
#   'Lng': -74.7819,
#   'Max Temp': 75.9,
#   'Humidity': 73,
#   'Cloudiness': 43,
#   'Wind Speed': 0.98,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Yar-Sale',
#   'Country': 'RU',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 34.43,
#   'Humidity': 80,
#   'Cloudiness': 2,
#   'Wind Speed': 6.49,
#   'Current Description': 'clear sky'},
#  {'City': 'Catuday',
#   'Country': 'PH',
#   'Lat': 16.2923,
#   'Lng': 119.8062,
#   'Max Temp': 83.68,
#   'Humidity': 72,
#   'Cloudiness': 81,
#   'Wind Speed': 5.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 54.88,
#   'Humidity': 95,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Catalao',
#   'Country': 'BR',
#   'Lat': -18.1658,
#   'Lng': -47.9464,
#   'Max Temp': 69.3,
#   'Humidity': 59,
#   'Cloudiness': 14,
#   'Wind Speed': 7.27,
#   'Current Description': 'few clouds'},
#  {'City': 'Sawakin',
#   'Country': 'SD',
#   'Lat': 19.1059,
#   'Lng': 37.3321,
#   'Max Temp': 84.06,
#   'Humidity': 56,
#   'Cloudiness': 33,
#   'Wind Speed': 3.44,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Weingarten',
#   'Country': 'DE',
#   'Lat': 47.8,
#   'Lng': 9.6333,
#   'Max Temp': 59.02,
#   'Humidity': 98,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Current Description': 'broken clouds'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 84.88,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Current Description': 'few clouds'},
#  {'City': 'Shirokiy',
#   'Country': 'RU',
#   'Lat': 49.758,
#   'Lng': 129.523,
#   'Max Temp': 57.56,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 16.26,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dhidhdhoo',
#   'Country': 'MV',
#   'Lat': 6.8833,
#   'Lng': 73.1,
#   'Max Temp': 79.83,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 19.77,
#   'Current Description': 'light rain'},
#  {'City': 'Rabat',
#   'Country': 'MA',
#   'Lat': 33.9911,
#   'Lng': -6.8401,
#   'Max Temp': 66.04,
#   'Humidity': 94,
#   'Cloudiness': 98,
#   'Wind Speed': 0,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Viedma',
#   'Country': 'AR',
#   'Lat': -40.8135,
#   'Lng': -62.9967,
#   'Max Temp': 40.37,
#   'Humidity': 58,
#   'Cloudiness': 4,
#   'Wind Speed': 10.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Isangel',
#   'Country': 'VU',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 80.71,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 56.73,
#   'Humidity': 94,
#   'Cloudiness': 8,
#   'Wind Speed': 5.06,
#   'Current Description': 'clear sky'},
#  {'City': 'Carutapera',
#   'Country': 'BR',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 78.06,
#   'Humidity': 81,
#   'Cloudiness': 35,
#   'Wind Speed': 8.05,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lodja',
#   'Country': 'CD',
#   'Lat': -3.4833,
#   'Lng': 23.4333,
#   'Max Temp': 67.1,
#   'Humidity': 97,
#   'Cloudiness': 95,
#   'Wind Speed': 0.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Itaguai',
#   'Country': 'BR',
#   'Lat': -22.8522,
#   'Lng': -43.7753,
#   'Max Temp': 74.59,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Current Description': 'clear sky'},
#  {'City': 'Kutum',
#   'Country': 'SD',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 70.57,
#   'Humidity': 70,
#   'Cloudiness': 37,
#   'Wind Speed': 5.21,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sioux Lookout',
#   'Country': 'CA',
#   'Lat': 50.1001,
#   'Lng': -91.917,
#   'Max Temp': 53.98,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 52.29,
#   'Humidity': 82,
#   'Cloudiness': 88,
#   'Wind Speed': 13.06,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vila Franca Do Campo',
#   'Country': 'PT',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 70.2,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'College',
#   'Country': 'US',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': 35.58,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kedrovyy',
#   'Country': 'RU',
#   'Lat': 56.1667,
#   'Lng': 91.8167,
#   'Max Temp': 36.01,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 5.32,
#   'Current Description': 'few clouds'},
#  {'City': 'Mayumba',
#   'Country': 'GA',
#   'Lat': -3.432,
#   'Lng': 10.6554,
#   'Max Temp': 74.98,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 0.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vestmannaeyjar',
#   'Country': 'IS',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 42.3,
#   'Humidity': 74,
#   'Cloudiness': 98,
#   'Wind Speed': 19.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Penasco',
#   'Country': 'MX',
#   'Lat': 31.3167,
#   'Lng': -113.5333,
#   'Max Temp': 84.9,
#   'Humidity': 57,
#   'Cloudiness': 19,
# ...
#   'Lat': 54.1667,
#   'Lng': 25,
#   'Max Temp': 39.54,
#   'Humidity': 90,
#   'Cloudiness': 2,
#   'Wind Speed': 5.46,
#   'Current Description': 'clear sky'},
#  {'City': 'Gangawati',
#   'Country': 'IN',
#   'Lat': 15.4333,
#   'Lng': 76.5333,
#   'Max Temp': 74.5,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 10.74,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tura',
#   'Country': 'IN',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 84.67,
#   'Humidity': 72,
#   'Cloudiness': 10,
#   'Wind Speed': 1.39,
#   'Current Description': 'clear sky'},
#  {'City': 'Uige',
#   'Country': 'AO',
#   'Lat': -7.6087,
#   'Lng': 15.0613,
#   'Max Temp': 68.11,
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 2.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Garissa',
#   'Country': 'KE',
#   'Lat': -0.4536,
#   'Lng': 39.6401,
#   'Max Temp': 72.45,
#   'Humidity': 82,
#   'Cloudiness': 46,
#   'Wind Speed': 12.97,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Issoudun',
#   'Country': 'FR',
#   'Lat': 47,
#   'Lng': 1.8333,
#   'Max Temp': 59.65,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Idil',
#   'Country': 'TR',
#   'Lat': 37.3411,
#   'Lng': 41.8895,
#   'Max Temp': 63.88,
#   'Humidity': 23,
#   'Cloudiness': 17,
#   'Wind Speed': 5.66,
#   'Current Description': 'few clouds'},
#  {'City': 'Dolores',
#   'Country': 'AR',
#   'Lat': -36.3132,
#   'Lng': -57.6792,
#   'Max Temp': 51.1,
#   'Humidity': 73,
#   'Cloudiness': 99,
#   'Wind Speed': 11.14,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Esso',
#   'Country': 'RU',
#   'Lat': 55.9333,
#   'Lng': 158.7,
#   'Max Temp': 45.68,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 4.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Callaway',
#   'Country': 'US',
#   'Lat': 30.153,
#   'Lng': -85.5699,
#   'Max Temp': 75.9,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Current Description': 'broken clouds'},
#  {'City': 'Yangambi',
#   'Country': 'CD',
#   'Lat': 0.8102,
#   'Lng': 24.4336,
#   'Max Temp': 66.38,
#   'Humidity': 96,
#   'Cloudiness': 60,
#   'Wind Speed': 2.28,
#   'Current Description': 'broken clouds'},
#  {'City': 'Magadan',
#   'Country': 'RU',
#   'Lat': 59.5667,
#   'Lng': 150.8,
#   'Max Temp': 45.41,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 6.13,
#   'Current Description': 'clear sky'},
#  {'City': 'Inverell',
#   'Country': 'AU',
#   'Lat': -29.7833,
#   'Lng': 151.1167,
#   'Max Temp': 69.12,
#   'Humidity': 47,
#   'Cloudiness': 61,
#   'Wind Speed': 5.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vagur',
#   'Country': 'FO',
#   'Lat': 61.4732,
#   'Lng': -6.8119,
#   'Max Temp': 49.87,
#   'Humidity': 87,
#   'Cloudiness': 95,
#   'Wind Speed': 12.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tucurui',
#   'Country': 'BR',
#   'Lat': -3.7661,
#   'Lng': -49.6725,
#   'Max Temp': 78.03,
#   'Humidity': 74,
#   'Cloudiness': 24,
#   'Wind Speed': 6.15,
#   'Current Description': 'few clouds'},
#  {'City': 'Velasco Ibarra',
#   'Country': 'EC',
#   'Lat': -1.05,
#   'Lng': -79.6167,
#   'Max Temp': 76.57,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 3.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Santiago',
#   'Country': 'CL',
#   'Lat': -33.4569,
#   'Lng': -70.6483,
#   'Max Temp': 61.29,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Wasilla',
#   'Country': 'US',
#   'Lat': 61.5814,
#   'Lng': -149.4394,
#   'Max Temp': 46.89,
#   'Humidity': 58,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Rock Sound',
#   'Country': 'BS',
#   'Lat': 24.9,
#   'Lng': -76.2,
#   'Max Temp': 82.22,
#   'Humidity': 74,
#   'Cloudiness': 85,
#   'Wind Speed': 12.12,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Riachao Do Dantas',
#   'Country': 'BR',
#   'Lat': -11.0689,
#   'Lng': -37.725,
#   'Max Temp': 68.38,
#   'Humidity': 98,
#   'Cloudiness': 37,
#   'Wind Speed': 3.94,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Frontera',
#   'Country': 'MX',
#   'Lat': 26.9333,
#   'Lng': -101.45,
#   'Max Temp': 79.95,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 4.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vanimo',
#   'Country': 'PG',
#   'Lat': -2.6741,
#   'Lng': 141.3028,
#   'Max Temp': 85.57,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 5.93,
#   'Current Description': 'moderate rain'},
#  {'City': 'Puerto Barrios',
#   'Country': 'GT',
#   'Lat': 15.7167,
#   'Lng': -88.6,
#   'Max Temp': 80.15,
#   'Humidity': 95,
#   'Cloudiness': 96,
#   'Wind Speed': 1.83,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Labuan',
#   'Country': 'MY',
#   'Lat': 5.2767,
#   'Lng': 115.2417,
#   'Max Temp': 86.36,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 1.99,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Aloleng',
#   'Country': 'PH',
#   'Lat': 16.1307,
#   'Lng': 119.7824,
#   'Max Temp': 85.44,
#   'Humidity': 71,
#   'Cloudiness': 90,
#   'Wind Speed': 5.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mokhsogollokh',
#   'Country': 'RU',
#   'Lat': 61.4681,
#   'Lng': 128.9203,
#   'Max Temp': 44.8,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 12.39,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Formosa Do Rio Preto',
#   'Country': 'BR',
#   'Lat': -11.0483,
#   'Lng': -45.1931,
#   'Max Temp': 78.06,
#   'Humidity': 37,
#   'Cloudiness': 21,
#   'Wind Speed': 2.91,
#   'Current Description': 'few clouds'},
#  {'City': 'Ati',
#   'Country': 'TD',
#   'Lat': 13.2154,
#   'Lng': 18.3353,
#   'Max Temp': 81.34,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 7.94,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tocopilla',
#   'Country': 'CL',
#   'Lat': -22.092,
#   'Lng': -70.1979,
#   'Max Temp': 62.04,
#   'Humidity': 72,
#   'Cloudiness': 14,
#   'Wind Speed': 1.72,
#   'Current Description': 'few clouds'},
#  {'City': 'Bintulu',
#   'Country': 'MY',
#   'Lat': 3.1667,
#   'Lng': 113.0333,
#   'Max Temp': 88.21,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Boromo',
#   'Country': 'BF',
#   'Lat': 11.75,
#   'Lng': -2.9333,
#   'Max Temp': 77.13,
#   'Humidity': 71,
#   'Cloudiness': 48,
#   'Wind Speed': 6.42,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Umm Kaddadah',
#   'Country': 'SD',
#   'Lat': 13.6017,
#   'Lng': 26.6876,
#   'Max Temp': 80.31,
#   'Humidity': 59,
#   'Cloudiness': 11,
#   'Wind Speed': 5.19,
#   'Current Description': 'few clouds'},
#  {'City': 'Kota Belud',
#   'Country': 'MY',
#   'Lat': 6.351,
#   'Lng': 116.4305,
#   'Max Temp': 85.86,
#   'Humidity': 72,
#   'Cloudiness': 92,
#   'Wind Speed': 4.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Haicheng',
#   'Country': 'CN',
#   'Lat': 40.8516,
#   'Lng': 122.7475,
#   'Max Temp': 63.97,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Darnah',
#   'Country': 'LY',
#   'Lat': 32.767,
#   'Lng': 22.6367,
#   'Max Temp': 74.39,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 16.06,
#   'Current Description': 'clear sky'},
#  {'City': 'Mandalgovi',
#   'Country': 'MN',
#   'Lat': 45.7625,
#   'Lng': 106.2708,
#   'Max Temp': 57.07,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 18.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Golden',
#   'Country': 'US',
#   'Lat': 39.7555,
#   'Lng': -105.2211,
#   'Max Temp': 78.49,
#   'Humidity': 23,
#   'Cloudiness': 40,
#   'Wind Speed': 3,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Patacamaya',
#   'Country': 'BO',
#   'Lat': -17.2333,
#   'Lng': -67.9167,
#   'Max Temp': 45.52,
#   'Humidity': 80,
#   'Cloudiness': 11,
#   'Wind Speed': 8.77,
#   'Current Description': 'few clouds'},
#  {'City': 'Ust-Shonosha',
#   'Country': 'RU',
#   'Lat': 61.1531,
#   'Lng': 41.343,
#   'Max Temp': 45.82,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 6.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nagato',
#   'Country': 'JP',
#   'Lat': 34.3833,
#   'Lng': 131.2,
#   'Max Temp': 78.75,
#   'Humidity': 72,
#   'Cloudiness': 31,
#   'Wind Speed': 5.57,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kirakira',
#   'Country': 'SB',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 83.05,
#   'Humidity': 77,
#   'Cloudiness': 98,
#   'Wind Speed': 10.25,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lubao',
#   'Country': 'PH',
#   'Lat': 14.9167,
#   'Lng': 120.55,
#   'Max Temp': 89.67,
#   'Humidity': 66,
#   'Cloudiness': 28,
#   'Wind Speed': 3.85,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Erdenet',
#   'Country': 'MN',
#   'Lat': 49.0333,
#   'Lng': 104.0833,
#   'Max Temp': 45.9,
#   'Humidity': 40,
#   'Cloudiness': 36,
#   'Wind Speed': 4.85,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Dalbandin',
#   'Country': 'PK',
#   'Lat': 28.8947,
#   'Lng': 64.4101,
#   'Max Temp': 85.66,
#   'Humidity': 8,
#   'Cloudiness': 8,
#   'Wind Speed': 2.48,
#   'Current Description': 'clear sky'},
#  {'City': 'Cayenne',
#   'Country': 'GF',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 83.08,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 5.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bukoba',
#   'Country': 'TZ',
#   'Lat': -1.3317,
#   'Lng': 31.8122,
#   'Max Temp': 66.18,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Current Description': 'few clouds'},
#  {'City': 'Kimberley',
#   'Country': 'ZA',
#   'Lat': -28.7323,
#   'Lng': 24.7623,
#   'Max Temp': 58.69,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Pitimbu',
#   'Country': 'BR',
#   'Lat': -7.4706,
#   'Lng': -34.8086,
#   'Max Temp': 75.79,
#   'Humidity': 84,
#   'Cloudiness': 23,
#   'Wind Speed': 17.96,
#   'Current Description': 'few clouds'},
#  {'City': 'Joetsu',
#   'Country': 'JP',
#   'Lat': 37.1483,
#   'Lng': 138.2364,
#   'Max Temp': 81.72,
#   'Humidity': 59,
#   'Cloudiness': 32,
#   'Wind Speed': 7.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Teykovo',
#   'Country': 'RU',
#   'Lat': 56.858,
#   'Lng': 40.5369,
#   'Max Temp': 46.2,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.75,
#   'Current Description': 'light rain'},
#  {'City': 'Tongling',
#   'Country': 'CN',
#   'Lat': 30.95,
#   'Lng': 117.7833,
#   'Max Temp': 78.87,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 7.67,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Abalak',
#   'Country': 'RU',
#   'Lat': 58.1286,
#   'Lng': 68.5944,
#   'Max Temp': 38.19,
#   'Humidity': 65,
#   'Cloudiness': 71,
#   'Wind Speed': 9.55,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sangar',
#   'Country': 'RU',
#   'Lat': 63.9242,
#   'Lng': 127.4739,
#   'Max Temp': 43.59,
#   'Humidity': 71,
#   'Cloudiness': 73,
#   'Wind Speed': 2.37,
#   'Current Description': 'broken clouds'},
#  {'City': 'Montepuez',
#   'Country': 'MZ',
#   'Lat': -13.1256,
#   'Lng': 38.9997,
#   'Max Temp': 64.69,
#   'Humidity': 87,
#   'Cloudiness': 6,
#   'Wind Speed': 2.37,
#   'Current Description': 'clear sky'},
#  {'City': 'Bati',
#   'Country': 'ET',
#   'Lat': 11.1833,
#   'Lng': 40.0167,
#   'Max Temp': 65.7,
#   'Humidity': 55,
#   'Cloudiness': 24,
#   'Wind Speed': 6.15,
#   'Current Description': 'few clouds'},
#  {'City': 'Villa Carlos Paz',
#   'Country': 'AR',
#   'Lat': -31.4241,
#   'Lng': -64.4978,
#   'Max Temp': 59.4,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 4.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 60.85,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Missoula',
#   'Country': 'US',
#   'Lat': 47.0166,
#   'Lng': -113.8009,
#   'Max Temp': 63,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 3.31,
#   'Current Description': 'clear sky'},
#  {'City': 'Darhan',
#   'Country': 'MN',
#   'Lat': 49.4867,
#   'Lng': 105.9228,
#   'Max Temp': 46.17,
#   'Humidity': 51,
#   'Cloudiness': 93,
#   'Wind Speed': 2.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Svetlaya',
#   'Country': 'RU',
#   'Lat': 46.5389,
#   'Lng': 138.3297,
#   'Max Temp': 63.68,
#   'Humidity': 68,
#   'Cloudiness': 14,
#   'Wind Speed': 10.42,
#   'Current Description': 'few clouds'},
#  {'City': 'Knin',
#   'Country': 'HR',
#   'Lat': 44.0439,
#   'Lng': 16.2,
#   'Max Temp': 69.89,
#   'Humidity': 76,
#   'Cloudiness': 12,
#   'Wind Speed': 3.76,
#   'Current Description': 'few clouds'},
#  {'City': 'Tandil',
#   'Country': 'AR',
#   'Lat': -37.3217,
#   'Lng': -59.1332,
#   'Max Temp': 49.3,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Toowoomba',
#   'Country': 'AU',
#   'Lat': -27.55,
#   'Lng': 151.9667,
#   'Max Temp': 63.34,
#   'Humidity': 75,
#   'Cloudiness': 89,
#   'Wind Speed': 5.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vostok',
#   'Country': 'RU',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': 66.2,
#   'Humidity': 54,
#   'Cloudiness': 96,
#   'Wind Speed': 5.53,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nacimiento',
#   'Country': 'CL',
#   'Lat': -37.5,
#   'Lng': -72.6667,
#   'Max Temp': 41.68,
#   'Humidity': 78,
#   'Cloudiness': 71,
#   'Wind Speed': 6.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Naze',
#   'Country': 'JP',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 85.12,
#   'Humidity': 75,
#   'Cloudiness': 32,
#   'Wind Speed': 16.89,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nanganga',
#   'Country': 'TZ',
#   'Lat': -10.3833,
#   'Lng': 39.15,
#   'Max Temp': 65.93,
#   'Humidity': 97,
#   'Cloudiness': 40,
#   'Wind Speed': 1.95,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Prince Rupert',
#   'Country': 'CA',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 55.09,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Current Description': 'light rain'},
#  {'City': 'Nadym',
#   'Country': 'RU',
#   'Lat': 65.5333,
#   'Lng': 72.5167,
#   'Max Temp': 35.26,
#   'Humidity': 72,
#   'Cloudiness': 1,
#   'Wind Speed': 3.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Sterling',
#   'Country': 'US',
#   'Lat': 39.0062,
#   'Lng': -77.4286,
#   'Max Temp': 64.11,
#   'Humidity': 79,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Current Description': 'clear sky'},
#  {'City': 'Otane',
#   'Country': 'NZ',
#   'Lat': -39.8833,
#   'Lng': 176.6333,
#   'Max Temp': 52.02,
#   'Humidity': 91,
#   'Cloudiness': 96,
#   'Wind Speed': 7.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pedasi',
#   'Country': 'PA',
#   'Lat': 7.5333,
#   'Lng': -80.0333,
#   'Max Temp': 79.07,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 4.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fethiye',
#   'Country': 'TR',
#   'Lat': 36.6217,
#   'Lng': 29.1164,
#   'Max Temp': 58.87,
#   'Humidity': 42,
#   'Cloudiness': 89,
#   'Wind Speed': 4.43,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yashkul',
#   'Country': 'RU',
#   'Lat': 46.1711,
#   'Lng': 45.3435,
#   'Max Temp': 53.53,
#   'Humidity': 68,
#   'Cloudiness': 22,
#   'Wind Speed': 13.53,
#   'Current Description': 'few clouds'},
#  {'City': 'Amalner',
#   'Country': 'IN',
#   'Lat': 21.05,
#   'Lng': 75.0667,
#   'Max Temp': 79.45,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 10.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Narsaq',
#   'Country': 'GL',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 30.42,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 6.87,
#   'Current Description': 'clear sky'},
#  {'City': 'Talcahuano',
#   'Country': 'CL',
#   'Lat': -36.7167,
#   'Lng': -73.1167,
#   'Max Temp': 47.88,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Current Description': 'clear sky'},
#  {'City': 'Casper',
#   'Country': 'US',
#   'Lat': 42.8666,
#   'Lng': -106.3131,
#   'Max Temp': 67.5,
#   'Humidity': 25,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Mehamn',
#   'Country': 'NO',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 49.95,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vestmanna',
#   'Country': 'FO',
#   'Lat': 62.1564,
#   'Lng': -7.1664,
#   'Max Temp': 47.32,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Gasa      PS  31.5000   34.4667     76.98        67           0
# 1       Bulungu      CD  -4.5500   18.6000     70.21        90         100
# 2      Wakkanai      JP  45.4094  141.6739     67.98        68          40
# 3  Punta Arenas      CL -53.1500  -70.9167     41.11        81           0
# 4  Puerto Ayora      EC  -0.7393  -90.3518     69.22        90          87
# 5       Ushuaia      AR -54.8000  -68.3000     38.86        70           0
# 6       Salalah      OM  17.0151   54.0924     80.69        89          20
# 7    Nikolskoye      RU  59.7035   30.7861     47.88        98          72
# 8     Cape Town      ZA -33.9258   18.4232     60.12        79           0
# 9      Ampanihy      MG -24.7000   44.7500     68.18        66           0
#
#    Wind Speed Current Description
# 0        7.94           clear sky
# 1        1.59          light rain
# 2       11.50    scattered clouds
# 3       12.66           clear sky
# 4        6.91     overcast clouds
# 5        1.14           clear sky
# 6        1.14          few clouds
# 7        3.94       broken clouds
# 8        1.99           clear sky
# 9        5.32           clear sky

# %%
# Create the output file (CSV).
output_data_file = "weatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
